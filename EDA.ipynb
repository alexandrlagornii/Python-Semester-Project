# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Most commong Words

# %%
# Read in the document-term matrix and transpose it
import pandas as pd
data = pd.read_pickle('dtm.pkl')
data = data.transpose()
data.head()
# Out:
#            Trainspotting  The_Wrestler  Whiplash  Coco  Rocky  Oldboy
# ab                     0             0         0     0      0       1
# abandoned              0             0         0     1      0       0
# abbey                  0             0         0     0      0       1
# ability                0             2         0     0      0       0
# able                   0             1         3     0      0       3

# %%
# Find the top 30 words said in each episode
top_dict = {}
for c in data.columns:
    top = data[c].sort_values(ascending=False).head(30)
    top_dict[c] = list(zip(top.index, top.values))
    
top_dict
# Out:
# {'Trainspotting': [('fucking', 102),
#   ('im', 52),
#   ('like', 43),
#   ('got', 41),
#   ('going', 39),
#   ('just', 37),
#   ('right', 37),
#   ('tommy', 29),
#   ('fuck', 26),
#   ('good', 23),
#   ('youre', 23),
#   ('thats', 23),
#   ('man', 22),
#   ('dont', 21),
#   ('cunt', 21),
#   ('mark', 20),
#   ('spud', 18),
#   ('sorry', 17),
#   ('hit', 17),
#   ('choose', 17),
#   ('did', 17),
#   ('time', 17),
#   ('ive', 17),
#   ('youve', 16),
#   ('know', 16),
#   ('boy', 16),
#   ('need', 16),
#   ('way', 15),
#   ('begbie', 15),
#   ('come', 15)],
#  'The_Wrestler': [('yeah', 113),
#   ('ram', 103),
#   ('hey', 89),
#   ('im', 82),
#   ('oh', 78),
#   ('know', 75),
#   ('right', 75),
#   ('okay', 69),
#   ('dont', 64),
#   ('got', 61),
#   ('man', 59),
#   ('youre', 58),
#   ('come', 55),
#   ('just', 52),
#   ('good', 51),
#   ('uh', 49),
#   ('want', 46),
#   ('like', 41),
#   ('fuck', 39),
#   ('thats', 36),
#   ('gonna', 34),
#   ('randy', 30),
#   ('really', 29),
# ...

# %%
# Print the top 15 words said in each episode
for movie, top_words in top_dict.items():
    print(movie)
    print(', '.join([word for word, count in top_words[0:14]]))
    print('----')
# Out:
# Trainspotting
# fucking, im, like, got, going, just, right, tommy, fuck, good, youre, thats, man, dont
# ----
# The_Wrestler
# yeah, ram, hey, im, oh, know, right, okay, dont, got, man, youre, come, just
# ----
# Whiplash
# im, know, dont, yeah, fucking, right, just, okay, fuck, like, thats, gonna, youre, hey
# ----
# Coco
# im, family, la, miguel, dont, know, youre, want, just, like, music, papa, cruz, dante
# ----
# Rocky
# know, dont, hey, lm, got, like, yeah, good, rocky, come, aint, fight, youre, wanna
# ----
# Oldboy
# know, daesu, oh, im, dont, years, just, like, ill, right, really, did, come, want
# ----

# %%
# Add most common top words to stop word list
from collections import Counter

# Pulling out top 30 words for each episode
words = []
for movie in data.columns:
    top = [word for (word, count) in top_dict[movie]]
    for t in top:
        words.append(t)

words
# Out:
# ['fucking',
#  'im',
#  'like',
#  'got',
#  'going',
#  'just',
#  'right',
#  'tommy',
#  'fuck',
#  'good',
#  'youre',
#  'thats',
#  'man',
#  'dont',
#  'cunt',
#  'mark',
#  'spud',
#  'sorry',
#  'hit',
#  'choose',
#  'did',
#  'time',
#  'ive',
#  'youve',
#  'know',
#  'boy',
#  'need',
#  'way',
#  'begbie',
#  'come',
#  'yeah',
#  'ram',
#  'hey',
#  'im',
#  'oh',
#  'know',
#  'right',
#  'okay',
#  'dont',
#  'got',
#  'man',
#  'youre',
#  'come',
#  'just',
#  'good',
#  'uh',
#  'want',
#  'like',
#  'fuck',
#  'thats',
#  'gonna',
#  'randy',
#  'really',
#  'doing',
#  'seen',
#  'jam',
#  'think',
#  'ramjam',
#  'ill',
#  'whats',
#  'im',
#  'know',
#  'dont',
#  'yeah',
#  'fucking',
#  'right',
#  'just',
#  'okay',
#  'fuck',
#  'like',
#  'thats',
#  'gonna',
#  'youre',
#  'hey',
#  'time',
#  'really',
#  'good',
#  'neiman',
#  'sorry',
#  'play',
#  'band',
#  'got',
#  'think',
#  'did',
#  'come',
#  'man',
#  'lets',
#  'andrew',
#  'start',
# ...

# %%
# Appearence of common words
Counter(words).most_common()
# Out:
# [('like', 6),
#  ('just', 6),
#  ('youre', 6),
#  ('dont', 6),
#  ('know', 6),
#  ('come', 6),
#  ('im', 5),
#  ('got', 5),
#  ('right', 5),
#  ('good', 5),
#  ('thats', 4),
#  ('man', 4),
#  ('time', 4),
#  ('hey', 4),
#  ('okay', 4),
#  ('think', 4),
#  ('fuck', 3),
#  ('did', 3),
#  ('yeah', 3),
#  ('oh', 3),
#  ('want', 3),
#  ('gonna', 3),
#  ('really', 3),
#  ('fucking', 2),
#  ('going', 2),
#  ('sorry', 2),
#  ('need', 2),
#  ('ill', 2),
#  ('play', 2),
#  ('tell', 2),
#  ('tommy', 1),
#  ('cunt', 1),
#  ('mark', 1),
#  ('spud', 1),
#  ('hit', 1),
#  ('choose', 1),
#  ('ive', 1),
#  ('youve', 1),
#  ('boy', 1),
#  ('way', 1),
#  ('begbie', 1),
#  ('ram', 1),
#  ('uh', 1),
#  ('randy', 1),
#  ('doing', 1),
#  ('seen', 1),
#  ('jam', 1),
#  ('ramjam', 1),
#  ('whats', 1),
#  ('neiman', 1),
#  ('band', 1),
#  ('lets', 1),
#  ('andrew', 1),
#  ('start', 1),
#  ('connolly', 1),
#  ('family', 1),
#  ('la', 1),
#  ('miguel', 1),
#  ('music', 1),
#  ('papa', 1),
#  ('cruz', 1),
# ...

# %%
# If more than 3 movies have that word add it to stop list
add_stop_words = [word for word, count in Counter(words).most_common() if count > 3]

add_stop_words
# Out:
# ['like',
#  'just',
#  'youre',
#  'dont',
#  'know',
#  'come',
#  'im',
#  'got',
#  'right',
#  'good',
#  'thats',
#  'man',
#  'time',
#  'hey',
#  'okay',
#  'think']

# %%
# Update document-term matrix with the new list of stop words
from sklearn.feature_extraction import text
from sklearn.feature_extraction.text import CountVectorizer

# Read in cleaned data
data_clean = pd.read_pickle('data_clean.pkl')

# Add new stop words
stop_words = text.ENGLISH_STOP_WORDS.union(add_stop_words)

# Recreate document-term matrix
cv = CountVectorizer(stop_words=stop_words)
data_cv = cv.fit_transform(data_clean.transcript)
data_stop = pd.DataFrame(data_cv.toarray(), columns=cv.get_feature_names_out())
data_stop.index = data_clean.index

# Pickle it for later
import pickle
pickle.dump(cv, open("cv_stop.pkl", "wb"))
data_stop.to_pickle("dtm_stop.pkl")

# %%
# Check it
data_stop
# Out:
#                ab  abandoned  abbey  ability  able  aboutany  aboutim  \
# Trainspotting   0          0      0        0     0         0        0
# The_Wrestler    0          0      0        2     1         0        0
# Whiplash        0          0      0        0     3         0        0
# Coco            0          1      0        0     0         1        1
# Rocky           0          0      0        0     0         0        0
# Oldboy          1          0      1        0     3         0        0
#
#                abscess  absolute  absolutely  ...  zacks  zane  ziggy  zip  \
# Trainspotting        1         0           2  ...      0     0      1    0
# The_Wrestler         0         0           1  ...      0     0      0    0
# Whiplash             0         2           1  ...      0     1      0    0
# Coco                 0         0           0  ...      0     0      0    1
# Rocky                0         0           6  ...      1     0      0    0
# ...

# %%
# Transpose it
data_stop = data_stop.transpose()
data_stop.head()
# Out:
#            Trainspotting  The_Wrestler  Whiplash  Coco  Rocky  Oldboy
# ab                     0             0         0     0      0       1
# abandoned              0             0         0     1      0       0
# abbey                  0             0         0     0      0       1
# ability                0             2         0     0      0       0
# able                   0             1         3     0      0       3

# %%
# Find top 30 words for each movie
top_dict = {}
for c in data_stop.columns:
    top = data_stop[c].sort_values(ascending=False).head(30)
    top_dict[c] = list(zip(top.index, top.values))
    
top_dict
# Out:
# {'Trainspotting': [('fucking', 102),
#   ('going', 39),
#   ('tommy', 29),
#   ('fuck', 26),
#   ('cunt', 21),
#   ('mark', 20),
#   ('spud', 18),
#   ('choose', 17),
#   ('did', 17),
#   ('ive', 17),
#   ('hit', 17),
#   ('sorry', 17),
#   ('youve', 16),
#   ('boy', 16),
#   ('need', 16),
#   ('begbie', 15),
#   ('way', 15),
#   ('hes', 14),
#   ('yeah', 14),
#   ('ill', 14),
#   ('didnt', 13),
#   ('oh', 13),
#   ('mean', 13),
#   ('want', 12),
#   ('aye', 12),
#   ('really', 12),
#   ('sick', 12),
#   ('life', 12),
#   ('shite', 11),
#   ('say', 11)],
#  'The_Wrestler': [('yeah', 113),
#   ('ram', 103),
#   ('oh', 78),
#   ('uh', 49),
#   ('want', 46),
#   ('fuck', 39),
#   ('gonna', 34),
#   ('randy', 30),
#   ('really', 29),
#   ('doing', 28),
#   ('seen', 27),
#   ('jam', 27),
#   ('ill', 24),
#   ('whats', 24),
#   ('ramjam', 24),
#   ('little', 23),
#   ('fucking', 22),
#   ('look', 21),
#   ('ah', 21),
#   ('shit', 20),
#   ('leg', 19),
#   ('tell', 19),
#   ('thank', 18),
# ...

# %%
# Create wordcloud for each movie
from wordcloud import WordCloud

wc = WordCloud(stopwords=stop_words, background_color="white", colormap="Dark2",
               max_font_size=150, random_state=42)

# %%
# Reset the output dimensions
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [16, 6]

movies = ['Trainspotting', 'The_Wrestler', 'Whiplash', 'Coco', 'Rocky', 'Oldboy']

# Create subplots for each comedian
for index, movie in enumerate(data.columns):
    wc.generate(data_clean.transcript[movie])
    
    plt.subplot(3, 4, index+1)
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.title(movies[index])
    
plt.show()
